# %%
# %pip install imbalanced-learn
# %pip install tensorflow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: imbalanced-learn in /home/midhun/.local/lib/python3.10/site-packages (0.11.0)
# Requirement already satisfied: numpy>=1.17.3 in /home/midhun/.local/lib/python3.10/site-packages (from imbalanced-learn) (1.24.3)
# Requirement already satisfied: scikit-learn>=1.0.2 in /home/midhun/.local/lib/python3.10/site-packages (from imbalanced-learn) (1.3.0)
# Requirement already satisfied: joblib>=1.1.1 in /home/midhun/.local/lib/python3.10/site-packages (from imbalanced-learn) (1.3.2)
# Requirement already satisfied: scipy>=1.5.0 in /home/midhun/.local/lib/python3.10/site-packages (from imbalanced-learn) (1.11.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/midhun/.local/lib/python3.10/site-packages (from imbalanced-learn) (3.2.0)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow in /home/midhun/.local/lib/python3.10/site-packages (2.13.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/midhun/.local/lib/python3.10/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/midhun/.local/lib/python3.10/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /home/midhun/.local/lib/python3.10/site-packages (from tensorflow) (4.24.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/midhun/.local/lib/python3.10/site-packages (from tensorflow) (16.0.6)
# Requirement already satisfied: flatbuffers>=23.1.21 in /home/midhun/.local/lib/python3.10/site-packages (from tensorflow) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /home/midhun/.local/lib/python3.10/site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: keras<2.14,>=2.13.1 in /home/midhun/.local/lib/python3.10/site-packages (from tensorflow) (2.13.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/midhun/.local/lib/python3.10/site-packages (from tensorflow) (0.33.0)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in /home/midhun/.local/lib/python3.10/site-packages (from tensorflow) (2.13.0)
# Requirement already satisfied: packaging in /home/midhun/.local/lib/python3.10/site-packages (from tensorflow) (23.1)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from tensorflow) (59.6.0)
# Requirement already satisfied: wrapt>=1.11.0 in /home/midhun/.local/lib/python3.10/site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: six>=1.12.0 in /usr/lib/python3/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: absl-py>=1.0.0 in /home/midhun/.local/lib/python3.10/site-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: h5py>=2.9.0 in /home/midhun/.local/lib/python3.10/site-packages (from tensorflow) (3.9.0)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0 in /home/midhun/.local/lib/python3.10/site-packages (from tensorflow) (2.13.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/midhun/.local/lib/python3.10/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing-extensions<4.6.0,>=3.6.6 in /home/midhun/.local/lib/python3.10/site-packages (from tensorflow) (4.5.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/midhun/.local/lib/python3.10/site-packages (from tensorflow) (1.57.0)
# Requirement already satisfied: numpy<=1.24.3,>=1.22 in /home/midhun/.local/lib/python3.10/site-packages (from tensorflow) (1.24.3)
# Requirement already satisfied: termcolor>=1.1.0 in /home/midhun/.local/lib/python3.10/site-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/lib/python3/dist-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/midhun/.local/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow) (2.31.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/midhun/.local/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow) (2.3.7)
# Requirement already satisfied: markdown>=2.6.8 in /home/midhun/.local/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow) (3.4.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/midhun/.local/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow) (2.22.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/midhun/.local/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow) (0.7.1)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /home/midhun/.local/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow) (1.0.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/midhun/.local/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/midhun/.local/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/midhun/.local/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow) (0.3.0)
# Requirement already satisfied: urllib3<2.0 in /home/midhun/.local/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow) (1.26.16)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/midhun/.local/lib/python3.10/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow) (1.3.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow) (2020.6.20)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/midhun/.local/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow) (3.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/midhun/.local/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.14,>=2.13->tensorflow) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /home/midhun/.local/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/lib/python3/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow) (3.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder , OrdinalEncoder , LabelEncoder
import tensorflow as tf
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.utils.class_weight import compute_class_weight

# %%
Train=pd.read_csv("Train-1542865627584.csv")
Train_Beneficiarydata=pd.read_csv("Train_Beneficiarydata-1542865627584.csv")
Train_Inpatientdata=pd.read_csv("Train_Inpatientdata-1542865627584.csv")
Train_Outpatientdata=pd.read_csv("Train_Outpatientdata-1542865627584.csv")

# %% [markdown]
# # Merging data

# %%
Train_Allpatientdata=pd.merge(Train_Outpatientdata,Train_Inpatientdata,
                              left_on=['BeneID', 'ClaimID', 'ClaimStartDt', 'ClaimEndDt', 'Provider',
       'InscClaimAmtReimbursed', 'AttendingPhysician', 'OperatingPhysician',
       'OtherPhysician', 'ClmDiagnosisCode_1', 'ClmDiagnosisCode_2',
       'ClmDiagnosisCode_3', 'ClmDiagnosisCode_4', 'ClmDiagnosisCode_5',
       'ClmDiagnosisCode_6', 'ClmDiagnosisCode_7', 'ClmDiagnosisCode_8',
       'ClmDiagnosisCode_9', 'ClmDiagnosisCode_10', 'ClmProcedureCode_1',
       'ClmProcedureCode_2', 'ClmProcedureCode_3', 'ClmProcedureCode_4',
       'ClmProcedureCode_5', 'ClmProcedureCode_6', 'DeductibleAmtPaid',
       'ClmAdmitDiagnosisCode'],
                              right_on=['BeneID', 'ClaimID', 'ClaimStartDt', 'ClaimEndDt', 'Provider',
       'InscClaimAmtReimbursed', 'AttendingPhysician', 'OperatingPhysician',
       'OtherPhysician', 'ClmDiagnosisCode_1', 'ClmDiagnosisCode_2',
       'ClmDiagnosisCode_3', 'ClmDiagnosisCode_4', 'ClmDiagnosisCode_5',
       'ClmDiagnosisCode_6', 'ClmDiagnosisCode_7', 'ClmDiagnosisCode_8',
       'ClmDiagnosisCode_9', 'ClmDiagnosisCode_10', 'ClmProcedureCode_1',
       'ClmProcedureCode_2', 'ClmProcedureCode_3', 'ClmProcedureCode_4',
       'ClmProcedureCode_5', 'ClmProcedureCode_6', 'DeductibleAmtPaid',
       'ClmAdmitDiagnosisCode']
                              ,how='outer')

# %%
Train_Allpatientdata=pd.merge(Train_Allpatientdata,Train_Beneficiarydata,on="BeneID")

# %%
Train_Allpatientdata=pd.merge(Train_Allpatientdata,Train,on="Provider")

# %%
Train_Allpatientdata.shape
# Out:
# (558211, 55)

# %%
Train_Allpatientdata.head(5)
# Out:
#       BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11002  CLM624349   2009-10-11  2009-10-11  PRV56011
# 1  BENE11004  CLM121801   2009-01-06  2009-01-06  PRV56011
# 2  BENE11004  CLM150998   2009-01-22  2009-01-22  PRV56011
# 3  BENE11004  CLM173224   2009-02-03  2009-02-03  PRV56011
# 4  BENE11004  CLM224741   2009-03-03  2009-03-03  PRV56011
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                      30          PHY326117                NaN
# 1                      40          PHY334319                NaN
# 2                     200          PHY403831                NaN
# 3                      20          PHY339887                NaN
# 4                      40          PHY345721                NaN
#
#   OtherPhysician ClmDiagnosisCode_1  ... ChronicCond_Diabetes  \
# 0            NaN              78943  ...                    2
# 1            NaN              71988  ...                    1
# 2            NaN              82382  ...                    1
# 3            NaN              20381  ...                    1
# 4            NaN              V6546  ...                    1
#
#   ChronicCond_IschemicHeart ChronicCond_Osteoporasis  \
# 0                         2                        2
# 1                         1                        1
# 2                         1                        1
# 3                         1                        1
# 4                         1                        1
#
#   ChronicCond_rheumatoidarthritis ChronicCond_stroke IPAnnualReimbursementAmt  \
# 0                               2                  2                        0
# 1                               1                  2                        0
# 2                               1                  2                        0
# 3                               1                  2                        0
# 4                               1                  2                        0
#
#   IPAnnualDeductibleAmt OPAnnualReimbursementAmt OPAnnualDeductibleAmt  \
# 0                     0                       30                    50
# 1                     0                     1810                   760
# 2                     0                     1810                   760
# 3                     0                     1810                   760
# 4                     0                     1810                   760
#
#    PotentialFraud
# 0             Yes
# 1             Yes
# 2             Yes
# 3             Yes
# 4             Yes
#
# [5 rows x 55 columns]

# %%
Train_Allpatientdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 558211 entries, 0 to 558210
# Data columns (total 55 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   BeneID                           558211 non-null  object
#  1   ClaimID                          558211 non-null  object
#  2   ClaimStartDt                     558211 non-null  object
#  3   ClaimEndDt                       558211 non-null  object
#  4   Provider                         558211 non-null  object
#  5   InscClaimAmtReimbursed           558211 non-null  int64
#  6   AttendingPhysician               556703 non-null  object
#  7   OperatingPhysician               114447 non-null  object
#  8   OtherPhysician                   199736 non-null  object
#  9   ClmDiagnosisCode_1               547758 non-null  object
#  10  ClmDiagnosisCode_2               362605 non-null  object
#  11  ClmDiagnosisCode_3               243055 non-null  object
#  12  ClmDiagnosisCode_4               164536 non-null  object
#  13  ClmDiagnosisCode_5               111924 non-null  object
#  14  ClmDiagnosisCode_6               84392 non-null   object
#  15  ClmDiagnosisCode_7               66177 non-null   object
#  16  ClmDiagnosisCode_8               53444 non-null   object
#  17  ClmDiagnosisCode_9               41815 non-null   object
#  18  ClmDiagnosisCode_10              5010 non-null    object
#  19  ClmProcedureCode_1               23310 non-null   float64
#  20  ClmProcedureCode_2               5490 non-null    float64
#  21  ClmProcedureCode_3               969 non-null     float64
#  22  ClmProcedureCode_4               118 non-null     float64
#  23  ClmProcedureCode_5               9 non-null       float64
#  24  ClmProcedureCode_6               0 non-null       float64
#  25  DeductibleAmtPaid                557312 non-null  float64
#  26  ClmAdmitDiagnosisCode            145899 non-null  object
#  27  AdmissionDt                      40474 non-null   object
#  28  DischargeDt                      40474 non-null   object
#  29  DiagnosisGroupCode               40474 non-null   object
#  30  DOB                              558211 non-null  object
#  31  DOD                              4131 non-null    object
#  32  Gender                           558211 non-null  int64
#  33  Race                             558211 non-null  int64
#  34  RenalDiseaseIndicator            558211 non-null  object
#  35  State                            558211 non-null  int64
#  36  County                           558211 non-null  int64
#  37  NoOfMonths_PartACov              558211 non-null  int64
#  38  NoOfMonths_PartBCov              558211 non-null  int64
#  39  ChronicCond_Alzheimer            558211 non-null  int64
#  40  ChronicCond_Heartfailure         558211 non-null  int64
#  41  ChronicCond_KidneyDisease        558211 non-null  int64
#  42  ChronicCond_Cancer               558211 non-null  int64
#  43  ChronicCond_ObstrPulmonary       558211 non-null  int64
#  44  ChronicCond_Depression           558211 non-null  int64
#  45  ChronicCond_Diabetes             558211 non-null  int64
#  46  ChronicCond_IschemicHeart        558211 non-null  int64
#  47  ChronicCond_Osteoporasis         558211 non-null  int64
#  48  ChronicCond_rheumatoidarthritis  558211 non-null  int64
#  49  ChronicCond_stroke               558211 non-null  int64
#  50  IPAnnualReimbursementAmt         558211 non-null  int64
#  51  IPAnnualDeductibleAmt            558211 non-null  int64
#  52  OPAnnualReimbursementAmt         558211 non-null  int64
#  53  OPAnnualDeductibleAmt            558211 non-null  int64
#  54  PotentialFraud                   558211 non-null  object
# dtypes: float64(7), int64(22), object(26)
# memory usage: 234.2+ MB

# %% [markdown]
# # Physician cols preprocessing

# %%
a=(Train_Allpatientdata["AttendingPhysician"]==Train_Allpatientdata["OperatingPhysician"])
b=(Train_Allpatientdata["OperatingPhysician"]==Train_Allpatientdata["OtherPhysician"])
c=(Train_Allpatientdata["AttendingPhysician"]==Train_Allpatientdata["OtherPhysician"])

print(a.sum())
print(b.sum())
print(c.sum())
print( (a+b).sum() ) # atten=oper=other
# Out:
# 61164
# 15884
# 85258
# 63872

# %%
def physician_same(row):
    atten_oper=row["AttendingPhysician"]==row["OperatingPhysician"]
    oper_other=row["OperatingPhysician"]==row["OtherPhysician"]
    atten_other=row["AttendingPhysician"]==row["OtherPhysician"]
    if atten_oper==True and oper_other==True:# atten = oper = other
        return 0
    elif atten_oper==True and oper_other==False:# atten = oper != other
        return 1
    elif atten_oper==False and oper_other==True:# atten != oper = other
        return 2
    else:# atten != oper != other
        return 3
    
phy_same=Train_Allpatientdata.apply(physician_same,axis=1)

# %%
Train_Allpatientdata["phy_same"]=phy_same

# %%
def physician_count(row,list_count):
    count=0
    for col in list_count:
        if pd.isnull(row[col]):
            continue
        else:
            count+=1
    return count
    
list_count=["AttendingPhysician","OperatingPhysician","OtherPhysician"]
phy_count=Train_Allpatientdata.apply(physician_count,axis=1,args=(list_count,))

# %%
Train_Allpatientdata["phy_count"]=phy_count

# %%
Train_Allpatientdata.head(4)
# Out:
#       BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11002  CLM624349   2009-10-11  2009-10-11  PRV56011
# 1  BENE11004  CLM121801   2009-01-06  2009-01-06  PRV56011
# 2  BENE11004  CLM150998   2009-01-22  2009-01-22  PRV56011
# 3  BENE11004  CLM173224   2009-02-03  2009-02-03  PRV56011
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                      30          PHY326117                NaN
# 1                      40          PHY334319                NaN
# 2                     200          PHY403831                NaN
# 3                      20          PHY339887                NaN
#
#   OtherPhysician ClmDiagnosisCode_1  ... ChronicCond_Osteoporasis  \
# 0            NaN              78943  ...                        2
# 1            NaN              71988  ...                        1
# 2            NaN              82382  ...                        1
# 3            NaN              20381  ...                        1
#
#   ChronicCond_rheumatoidarthritis ChronicCond_stroke IPAnnualReimbursementAmt  \
# 0                               2                  2                        0
# 1                               1                  2                        0
# 2                               1                  2                        0
# 3                               1                  2                        0
#
#   IPAnnualDeductibleAmt OPAnnualReimbursementAmt OPAnnualDeductibleAmt  \
# 0                     0                       30                    50
# 1                     0                     1810                   760
# 2                     0                     1810                   760
# 3                     0                     1810                   760
#
#   PotentialFraud phy_same  phy_count
# 0            Yes        3          1
# 1            Yes        3          1
# 2            Yes        3          1
# 3            Yes        3          1
#
# [4 rows x 57 columns]

# %% [markdown]
# # ClainStartDt , ClainEndDt cols preprocessing

# %%
startdate= pd.to_datetime( Train_Allpatientdata["ClaimStartDt"] )
enddate= pd.to_datetime( Train_Allpatientdata["ClaimEndDt"] )

period = ( enddate - startdate).dt.days
Train_Allpatientdata["period"] = period

# %%
Train_Allpatientdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 558211 entries, 0 to 558210
# Data columns (total 58 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   BeneID                           558211 non-null  object
#  1   ClaimID                          558211 non-null  object
#  2   ClaimStartDt                     558211 non-null  object
#  3   ClaimEndDt                       558211 non-null  object
#  4   Provider                         558211 non-null  object
#  5   InscClaimAmtReimbursed           558211 non-null  int64
#  6   AttendingPhysician               556703 non-null  object
#  7   OperatingPhysician               114447 non-null  object
#  8   OtherPhysician                   199736 non-null  object
#  9   ClmDiagnosisCode_1               547758 non-null  object
#  10  ClmDiagnosisCode_2               362605 non-null  object
#  11  ClmDiagnosisCode_3               243055 non-null  object
#  12  ClmDiagnosisCode_4               164536 non-null  object
#  13  ClmDiagnosisCode_5               111924 non-null  object
#  14  ClmDiagnosisCode_6               84392 non-null   object
#  15  ClmDiagnosisCode_7               66177 non-null   object
#  16  ClmDiagnosisCode_8               53444 non-null   object
#  17  ClmDiagnosisCode_9               41815 non-null   object
#  18  ClmDiagnosisCode_10              5010 non-null    object
#  19  ClmProcedureCode_1               23310 non-null   float64
#  20  ClmProcedureCode_2               5490 non-null    float64
#  21  ClmProcedureCode_3               969 non-null     float64
#  22  ClmProcedureCode_4               118 non-null     float64
#  23  ClmProcedureCode_5               9 non-null       float64
#  24  ClmProcedureCode_6               0 non-null       float64
#  25  DeductibleAmtPaid                557312 non-null  float64
#  26  ClmAdmitDiagnosisCode            145899 non-null  object
#  27  AdmissionDt                      40474 non-null   object
#  28  DischargeDt                      40474 non-null   object
#  29  DiagnosisGroupCode               40474 non-null   object
#  30  DOB                              558211 non-null  object
#  31  DOD                              4131 non-null    object
#  32  Gender                           558211 non-null  int64
#  33  Race                             558211 non-null  int64
#  34  RenalDiseaseIndicator            558211 non-null  object
#  35  State                            558211 non-null  int64
#  36  County                           558211 non-null  int64
#  37  NoOfMonths_PartACov              558211 non-null  int64
#  38  NoOfMonths_PartBCov              558211 non-null  int64
#  39  ChronicCond_Alzheimer            558211 non-null  int64
#  40  ChronicCond_Heartfailure         558211 non-null  int64
#  41  ChronicCond_KidneyDisease        558211 non-null  int64
#  42  ChronicCond_Cancer               558211 non-null  int64
#  43  ChronicCond_ObstrPulmonary       558211 non-null  int64
#  44  ChronicCond_Depression           558211 non-null  int64
#  45  ChronicCond_Diabetes             558211 non-null  int64
#  46  ChronicCond_IschemicHeart        558211 non-null  int64
#  47  ChronicCond_Osteoporasis         558211 non-null  int64
#  48  ChronicCond_rheumatoidarthritis  558211 non-null  int64
#  49  ChronicCond_stroke               558211 non-null  int64
#  50  IPAnnualReimbursementAmt         558211 non-null  int64
#  51  IPAnnualDeductibleAmt            558211 non-null  int64
#  52  OPAnnualReimbursementAmt         558211 non-null  int64
#  53  OPAnnualDeductibleAmt            558211 non-null  int64
#  54  PotentialFraud                   558211 non-null  object
#  55  phy_same                         558211 non-null  int64
#  56  phy_count                        558211 non-null  int64
#  57  period                           558211 non-null  int64
# dtypes: float64(7), int64(25), object(26)
# memory usage: 247.0+ MB

# %% [markdown]
# ## taking copy

# %%
copy1=Train_Allpatientdata.copy()

# %% [markdown]
# # Cronic code cols preprocessing

# %%
cronic_cols_names=copy1.columns[ copy1.columns.str.startswith("ChronicCond") ]
cronic_cols=copy1[   cronic_cols_names   ]
cronic=cronic_cols.replace({2:0})
copy1[   cronic_cols_names   ]=cronic

# %% [markdown]
# # Potintial fraud preprocessing

# %%
copy1["PotentialFraud"]=copy1["PotentialFraud"].replace({"Yes":1,"No":0})

# %% [markdown]
# # gender preprocessing

# %%
copy1["Gender"]=copy1["Gender"].replace({2:0})

# %% [markdown]
# # Admisson data preprocessing

# %%
startadmt= pd.to_datetime( copy1["AdmissionDt"] )
enddatadmt= pd.to_datetime( copy1["DischargeDt"] )

periodadmt = ( enddatadmt - startadmt).dt.days
copy1["periodadmt"] = periodadmt
copy1["periodadmt"]=copy1["periodadmt"].fillna(0)

# %% [markdown]
# # RenalDiseaseIndicator preprocessing

# %%
copy1["RenalDiseaseIndicator"]=copy1["RenalDiseaseIndicator"].replace({"Y":1})

# %% [markdown]
# # patient age preprocessing

# %%
birthdate=pd.to_datetime(copy1["DOB"])
enddate=pd.to_datetime(copy1["DOD"])

# cheack whether the patient dead or alife
def alife_function(value):
    if value==True:
        return 1
    else:
        return 0
alife = pd.isna(enddate).apply(alife_function)


# get the age of patient
max_date=enddate.dropna().max()
enddate[pd.isna(enddate)]=max_date
period=(((enddate-birthdate).dt.days/356).astype(int))

copy1["age"]=period
copy1["alife"]=alife

# %%
copy1.head(2)
# Out:
#       BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11002  CLM624349   2009-10-11  2009-10-11  PRV56011
# 1  BENE11004  CLM121801   2009-01-06  2009-01-06  PRV56011
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                      30          PHY326117                NaN
# 1                      40          PHY334319                NaN
#
#   OtherPhysician ClmDiagnosisCode_1  ... IPAnnualDeductibleAmt  \
# 0            NaN              78943  ...                     0
# 1            NaN              71988  ...                     0
#
#   OPAnnualReimbursementAmt OPAnnualDeductibleAmt PotentialFraud phy_same  \
# 0                       30                    50              1        3
# 1                     1810                   760              1        3
#
#   phy_count period periodadmt age  alife
# 0         1      0        0.0  75      1
# 1         1      0        0.0  89      1
#
# [2 rows x 61 columns]

# %%
copy1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 558211 entries, 0 to 558210
# Data columns (total 61 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   BeneID                           558211 non-null  object
#  1   ClaimID                          558211 non-null  object
#  2   ClaimStartDt                     558211 non-null  object
#  3   ClaimEndDt                       558211 non-null  object
#  4   Provider                         558211 non-null  object
#  5   InscClaimAmtReimbursed           558211 non-null  int64
#  6   AttendingPhysician               556703 non-null  object
#  7   OperatingPhysician               114447 non-null  object
#  8   OtherPhysician                   199736 non-null  object
#  9   ClmDiagnosisCode_1               547758 non-null  object
#  10  ClmDiagnosisCode_2               362605 non-null  object
#  11  ClmDiagnosisCode_3               243055 non-null  object
#  12  ClmDiagnosisCode_4               164536 non-null  object
#  13  ClmDiagnosisCode_5               111924 non-null  object
#  14  ClmDiagnosisCode_6               84392 non-null   object
#  15  ClmDiagnosisCode_7               66177 non-null   object
#  16  ClmDiagnosisCode_8               53444 non-null   object
#  17  ClmDiagnosisCode_9               41815 non-null   object
#  18  ClmDiagnosisCode_10              5010 non-null    object
#  19  ClmProcedureCode_1               23310 non-null   float64
#  20  ClmProcedureCode_2               5490 non-null    float64
#  21  ClmProcedureCode_3               969 non-null     float64
#  22  ClmProcedureCode_4               118 non-null     float64
#  23  ClmProcedureCode_5               9 non-null       float64
#  24  ClmProcedureCode_6               0 non-null       float64
#  25  DeductibleAmtPaid                557312 non-null  float64
#  26  ClmAdmitDiagnosisCode            145899 non-null  object
#  27  AdmissionDt                      40474 non-null   object
#  28  DischargeDt                      40474 non-null   object
#  29  DiagnosisGroupCode               40474 non-null   object
#  30  DOB                              558211 non-null  object
#  31  DOD                              4131 non-null    object
#  32  Gender                           558211 non-null  int64
#  33  Race                             558211 non-null  int64
#  34  RenalDiseaseIndicator            558211 non-null  object
#  35  State                            558211 non-null  int64
#  36  County                           558211 non-null  int64
#  37  NoOfMonths_PartACov              558211 non-null  int64
#  38  NoOfMonths_PartBCov              558211 non-null  int64
#  39  ChronicCond_Alzheimer            558211 non-null  int64
#  40  ChronicCond_Heartfailure         558211 non-null  int64
#  41  ChronicCond_KidneyDisease        558211 non-null  int64
#  42  ChronicCond_Cancer               558211 non-null  int64
#  43  ChronicCond_ObstrPulmonary       558211 non-null  int64
#  44  ChronicCond_Depression           558211 non-null  int64
#  45  ChronicCond_Diabetes             558211 non-null  int64
#  46  ChronicCond_IschemicHeart        558211 non-null  int64
#  47  ChronicCond_Osteoporasis         558211 non-null  int64
#  48  ChronicCond_rheumatoidarthritis  558211 non-null  int64
#  49  ChronicCond_stroke               558211 non-null  int64
#  50  IPAnnualReimbursementAmt         558211 non-null  int64
#  51  IPAnnualDeductibleAmt            558211 non-null  int64
#  52  OPAnnualReimbursementAmt         558211 non-null  int64
#  53  OPAnnualDeductibleAmt            558211 non-null  int64
#  54  PotentialFraud                   558211 non-null  int64
#  55  phy_same                         558211 non-null  int64
#  56  phy_count                        558211 non-null  int64
#  57  period                           558211 non-null  int64
#  58  periodadmt                       558211 non-null  float64
#  59  age                              558211 non-null  int64
#  60  alife                            558211 non-null  int64
# dtypes: float64(8), int64(28), object(25)
# memory usage: 259.8+ MB

# %% [markdown]
# # means and stds

# %%
def groupby(df,by,vars_to_group,methods,col_ident,as_index=True,agg=False):
    if agg:
        grouped=df.groupby(by=by,as_index=as_index)[vars_to_group].agg(methods)
        cols=['_'.join(col) for col in grouped.columns.values]
        cols=[col_ident+"_"+col for col in cols]
        grouped.columns=cols
        return grouped
    
    else:
        concat=df.groupby(by=by,as_index=as_index)[vars_to_group].transform(methods[0])
        cols=[ col_ident+"_"+col+"_"+methods[0] for col in concat.columns ]
        concat.columns=cols
        
        for method in methods[1:]:
            grouped=df.groupby(by=by,as_index=as_index)[vars_to_group].transform(method)
            cols=[col_ident+"_"+col+"_"+method for col in grouped.columns]
            grouped.columns=cols
            concat=pd.concat([concat,grouped],axis=1)
        
        return concat

# %%
money_cols=["InscClaimAmtReimbursed","DeductibleAmtPaid","NoOfMonths_PartACov","NoOfMonths_PartBCov",
           "IPAnnualReimbursementAmt","IPAnnualDeductibleAmt","OPAnnualReimbursementAmt","OPAnnualDeductibleAmt"]

# %%
provider_money=groupby(copy1,["Provider"],money_cols,["mean","std"],"provider",
                       True,False)

# %%
banel_money=groupby(copy1,["BeneID"],money_cols,["mean","std"],"banel",
                       True,False)

# %%
diag1_money=groupby(copy1,["ClmDiagnosisCode_1"],money_cols,["mean","std"],"diag1",
                       True,False)

# %%
selected_cols_names=["phy_same","phy_count","period","periodadmt","age","alife","Provider","PotentialFraud"]
selected_cols=copy1[selected_cols_names]

# %%
data=pd.concat([selected_cols,provider_money,banel_money,diag1_money],axis=1)

# %%
grouped=data.groupby(by=["Provider","PotentialFraud"]).agg("mean").reset_index()

# %%
grouped
# Out:
#       Provider  PotentialFraud  phy_same  phy_count    period  periodadmt  \
# 0     PRV51001               0  2.960000   1.600000  1.440000    1.000000
# 1     PRV51003               1  2.439394   1.530303  3.674242    2.424242
# 2     PRV51004               0  2.818792   1.604027  1.429530    0.000000
# 3     PRV51005               1  2.731330   1.599142  1.088412    0.000000
# 4     PRV51007               0  2.736111   1.527778  0.958333    0.222222
# ...        ...             ...       ...        ...       ...         ...
# 5405  PRV57759               0  2.892857   1.464286  2.142857    0.000000
# 5406  PRV57760               0  2.318182   1.681818  0.318182    0.000000
# 5407  PRV57761               0  3.000000   1.609756  1.390244    0.000000
# 5408  PRV57762               0  3.000000   1.000000  0.000000    0.000000
# 5409  PRV57763               0  2.601695   1.576271  1.720339    0.000000
#
#             age     alife  provider_InscClaimAmtReimbursed_mean  \
# 0     80.240000  1.000000                           4185.600000
# 1     71.371212  0.992424                           4588.409091
# 2     73.516779  0.993289                            350.134228
# 3     71.783691  0.996567                            241.124464
# 4     70.583333  0.986111                            468.194444
# ...         ...       ...                                   ...
# 5405  75.285714  1.000000                            380.000000
# 5406  62.318182  1.000000                            216.818182
# 5407  73.268293  0.987805                            225.243902
# 5408  69.000000  1.000000                           1900.000000
# 5409  75.423729  1.000000                            369.576271
#
#       provider_DeductibleAmtPaid_mean  ...  \
# 0                          213.600000  ...
# 1                          502.166667  ...
# 2                            2.080537  ...
# 3                            3.175966  ...
# 4                           45.333333  ...
# ...                               ...  ...
# 5405                         4.642857  ...
# 5406                         0.000000  ...
# 5407                         4.512195  ...
# 5408                         0.000000  ...
# 5409                         3.305085  ...
#
#       diag1_OPAnnualReimbursementAmt_mean  diag1_OPAnnualDeductibleAmt_mean  \
# 0                             1804.331094                        543.045084
# 1                             2422.458599                        676.313985
# 2                             2430.017927                        694.246881
# 3                             2195.953526                        630.805985
# 4                             2089.969651                        606.550334
# ...                                   ...                               ...
# 5405                          2770.995487                        762.684094
# 5406                          1857.020747                        551.812490
# 5407                          2409.246660                        667.100333
# 5408                          2332.103825                        701.530055
# 5409                          2324.141731                        667.799460
#
#       diag1_InscClaimAmtReimbursed_std  diag1_DeductibleAmtPaid_std  \
# 0                          3482.066310                   161.353027
# 1                          4017.871066                   260.257069
# 2                          1536.290845                   113.086257
# 3                          1234.005090                    91.141252
# 4                          1519.425993                   103.302166
# ...                                ...                          ...
# 5405                        924.661538                    88.673186
# 5406                       1182.800362                    63.746284
# 5407                       1469.587798                    89.369298
# 5408                        926.436661                   146.810805
# 5409                       1036.401611                    82.166327
#
#       diag1_NoOfMonths_PartACov_std  diag1_NoOfMonths_PartBCov_std  \
# 0                          0.569945                       0.424192
# 1                          0.726572                       0.653285
# 2                          0.667719                       0.577420
# 3                          0.657071                       0.565930
# 4                          0.626542                       0.520122
# ...                             ...                            ...
# 5405                       0.717266                       0.575517
# 5406                       0.738778                       0.632455
# 5407                       0.626573                       0.503166
# 5408                       0.939796                       0.000000
# 5409                       0.689070                       0.606932
#
#       diag1_IPAnnualReimbursementAmt_std  diag1_IPAnnualDeductibleAmt_std  \
# 0                           12941.552352                      1205.297144
# 1                           12620.604411                      1226.306633
# 2                           11016.516937                      1111.592405
# 3                           10021.329572                       957.701391
# 4                           10565.761429                      1126.358206
# ...                                  ...                              ...
# 5405                        11706.835391                       989.925167
# 5406                        10087.266945                       852.726747
# 5407                         9701.587916                       956.791480
# 5408                        10836.121659                       798.136760
# 5409                        10163.343892                       961.863114
#
#       diag1_OPAnnualReimbursementAmt_std  diag1_OPAnnualDeductibleAmt_std
# 0                            2450.076771                       661.506672
# 1                            3369.338617                       848.213675
# 2                            2972.377916                       808.138208
# 3                            2727.944083                       737.419878
# 4                            2486.827069                       682.279276
# ...                                  ...                              ...
# 5405                         3092.516228                       805.101036
# 5406                         2325.052621                       667.813928
# 5407                         2864.403847                       730.914731
# 5408                         2327.892739                       625.238022
# 5409                         2735.861878                       769.458419
#
# [5410 rows x 56 columns]

# %%
grouped=grouped.fillna(0)

# %%
features=grouped.iloc[:,2:]
labels=grouped.iloc[:,1]

# %%
features.columns
# Out:
# Index(['phy_same', 'phy_count', 'period', 'periodadmt', 'age', 'alife',
#        'provider_InscClaimAmtReimbursed_mean',
#        'provider_DeductibleAmtPaid_mean', 'provider_NoOfMonths_PartACov_mean',
#        'provider_NoOfMonths_PartBCov_mean',
#        'provider_IPAnnualReimbursementAmt_mean',
#        'provider_IPAnnualDeductibleAmt_mean',
#        'provider_OPAnnualReimbursementAmt_mean',
#        'provider_OPAnnualDeductibleAmt_mean',
#        'provider_InscClaimAmtReimbursed_std', 'provider_DeductibleAmtPaid_std',
#        'provider_NoOfMonths_PartACov_std', 'provider_NoOfMonths_PartBCov_std',
#        'provider_IPAnnualReimbursementAmt_std',
#        'provider_IPAnnualDeductibleAmt_std',
#        'provider_OPAnnualReimbursementAmt_std',
#        'provider_OPAnnualDeductibleAmt_std',
#        'banel_InscClaimAmtReimbursed_mean', 'banel_DeductibleAmtPaid_mean',
#        'banel_NoOfMonths_PartACov_mean', 'banel_NoOfMonths_PartBCov_mean',
#        'banel_IPAnnualReimbursementAmt_mean',
#        'banel_IPAnnualDeductibleAmt_mean',
#        'banel_OPAnnualReimbursementAmt_mean',
#        'banel_OPAnnualDeductibleAmt_mean', 'banel_InscClaimAmtReimbursed_std',
#        'banel_DeductibleAmtPaid_std', 'banel_NoOfMonths_PartACov_std',
#        'banel_NoOfMonths_PartBCov_std', 'banel_IPAnnualReimbursementAmt_std',
#        'banel_IPAnnualDeductibleAmt_std', 'banel_OPAnnualReimbursementAmt_std',
#        'banel_OPAnnualDeductibleAmt_std', 'diag1_InscClaimAmtReimbursed_mean',
#        'diag1_DeductibleAmtPaid_mean', 'diag1_NoOfMonths_PartACov_mean',
#        'diag1_NoOfMonths_PartBCov_mean', 'diag1_IPAnnualReimbursementAmt_mean',
#        'diag1_IPAnnualDeductibleAmt_mean',
#        'diag1_OPAnnualReimbursementAmt_mean',
#        'diag1_OPAnnualDeductibleAmt_mean', 'diag1_InscClaimAmtReimbursed_std',
#        'diag1_DeductibleAmtPaid_std', 'diag1_NoOfMonths_PartACov_std',
#        'diag1_NoOfMonths_PartBCov_std', 'diag1_IPAnnualReimbursementAmt_std',
#        'diag1_IPAnnualDeductibleAmt_std', 'diag1_OPAnnualReimbursementAmt_std',
#        'diag1_OPAnnualDeductibleAmt_std'],
#       dtype='object')

# %%
from imblearn.over_sampling import SMOTE
oversample = SMOTE()
features, labels = oversample.fit_resample(features, labels)

# %%
scaler = StandardScaler()
featuresstand=scaler.fit_transform(features)

# %%
ff=compute_class_weight(class_weight="balanced",classes=np.unique(labels),y=labels)
cw=dict(zip(np.unique(labels),ff))

featuress,labelss=shuffle(featuresstand,labels)
xtrain,xtest,ytrain,ytest = train_test_split(featuress,labelss,test_size=0.1)

# %%
xtrain=xtrain.astype(np.float32)
xtest=xtest.astype(np.float32)
ytrain=ytrain.astype(np.float32).to_numpy()
ytest=ytest.astype(np.float32).to_numpy()


ytrain=ytrain.reshape(ytrain.shape+(1,))
ytest=ytest.reshape(ytest.shape+(1,))

print(xtrain.shape)
print(xtest.shape)
print(ytrain.shape)
print(ytest.shape)
# Out:
# (8827, 54)
# (981, 54)
# (8827, 1)
# (981, 1)

# %%
inpt=tf.keras.layers.Input((xtrain.shape[1]))
d1=tf.keras.layers.Dense(256, activation='relu')(inpt)
d1=tf.keras.layers.Dense(128, activation='relu')(d1)

d2=tf.keras.layers.Dense(1,activation="sigmoid")(d1)

nural_network=tf.keras.Model(inputs=inpt,outputs=d2)

# %%
nural_network.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
                      loss='binary_crossentropy'
                    ,metrics=["accuracy"])

history_combined=nural_network.fit(xtrain,ytrain,validation_data=(xtest,ytest),batch_size=128,epochs=300,
                                  class_weight=cw)
# Out:
# Epoch 1/300
# 69/69 [==============================] - 1s 3ms/step - loss: 0.5969 - accuracy: 0.6740 - val_loss: 0.5202 - val_accuracy: 0.7227
# Epoch 2/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.4773 - accuracy: 0.7655 - val_loss: 0.4482 - val_accuracy: 0.8022
# Epoch 3/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.4175 - accuracy: 0.8304 - val_loss: 0.4015 - val_accuracy: 0.8359
# Epoch 4/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.3780 - accuracy: 0.8508 - val_loss: 0.3720 - val_accuracy: 0.8491
# Epoch 5/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.3511 - accuracy: 0.8613 - val_loss: 0.3523 - val_accuracy: 0.8593
# Epoch 6/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.3316 - accuracy: 0.8661 - val_loss: 0.3386 - val_accuracy: 0.8644
# Epoch 7/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.3164 - accuracy: 0.8695 - val_loss: 0.3291 - val_accuracy: 0.8726
# Epoch 8/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.3048 - accuracy: 0.8750 - val_loss: 0.3208 - val_accuracy: 0.8726
# Epoch 9/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.2951 - accuracy: 0.8806 - val_loss: 0.3139 - val_accuracy: 0.8726
# Epoch 10/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.2867 - accuracy: 0.8835 - val_loss: 0.3091 - val_accuracy: 0.8777
# Epoch 11/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.2794 - accuracy: 0.8871 - val_loss: 0.3041 - val_accuracy: 0.8756
# Epoch 12/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.2732 - accuracy: 0.8906 - val_loss: 0.2998 - val_accuracy: 0.8797
# Epoch 13/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.2672 - accuracy: 0.8952 - val_loss: 0.2965 - val_accuracy: 0.8818
# Epoch 14/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.2623 - accuracy: 0.8971 - val_loss: 0.2922 - val_accuracy: 0.8848
# Epoch 15/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.2572 - accuracy: 0.9003 - val_loss: 0.2893 - val_accuracy: 0.8848
# Epoch 16/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.2526 - accuracy: 0.9026 - val_loss: 0.2860 - val_accuracy: 0.8869
# Epoch 17/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.2484 - accuracy: 0.9039 - val_loss: 0.2824 - val_accuracy: 0.8848
# Epoch 18/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.2441 - accuracy: 0.9046 - val_loss: 0.2797 - val_accuracy: 0.8889
# Epoch 19/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.2397 - accuracy: 0.9072 - val_loss: 0.2757 - val_accuracy: 0.8879
# Epoch 20/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.2358 - accuracy: 0.9071 - val_loss: 0.2726 - val_accuracy: 0.8889
# Epoch 21/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.2324 - accuracy: 0.9085 - val_loss: 0.2704 - val_accuracy: 0.8899
# Epoch 22/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.2285 - accuracy: 0.9108 - val_loss: 0.2710 - val_accuracy: 0.8930
# Epoch 23/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.2257 - accuracy: 0.9145 - val_loss: 0.2644 - val_accuracy: 0.8909
# Epoch 24/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.2224 - accuracy: 0.9148 - val_loss: 0.2619 - val_accuracy: 0.8950
# Epoch 25/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.2186 - accuracy: 0.9176 - val_loss: 0.2594 - val_accuracy: 0.8960
# Epoch 26/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.2168 - accuracy: 0.9164 - val_loss: 0.2580 - val_accuracy: 0.8950
# Epoch 27/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.2129 - accuracy: 0.9218 - val_loss: 0.2546 - val_accuracy: 0.8940
# Epoch 28/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.2108 - accuracy: 0.9202 - val_loss: 0.2538 - val_accuracy: 0.8950
# Epoch 29/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.2073 - accuracy: 0.9218 - val_loss: 0.2503 - val_accuracy: 0.9001
# Epoch 30/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.2037 - accuracy: 0.9234 - val_loss: 0.2496 - val_accuracy: 0.8991
# Epoch 31/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.2021 - accuracy: 0.9260 - val_loss: 0.2470 - val_accuracy: 0.9032
# Epoch 32/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.1990 - accuracy: 0.9259 - val_loss: 0.2436 - val_accuracy: 0.8991
# Epoch 33/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.1961 - accuracy: 0.9290 - val_loss: 0.2419 - val_accuracy: 0.9021
# Epoch 34/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.1928 - accuracy: 0.9293 - val_loss: 0.2403 - val_accuracy: 0.9032
# Epoch 35/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.1907 - accuracy: 0.9315 - val_loss: 0.2403 - val_accuracy: 0.9001
# Epoch 36/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.1881 - accuracy: 0.9313 - val_loss: 0.2364 - val_accuracy: 0.9062
# Epoch 37/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.1858 - accuracy: 0.9328 - val_loss: 0.2324 - val_accuracy: 0.9052
# Epoch 38/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.1836 - accuracy: 0.9350 - val_loss: 0.2329 - val_accuracy: 0.9093
# Epoch 39/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.1810 - accuracy: 0.9354 - val_loss: 0.2287 - val_accuracy: 0.9052
# Epoch 40/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.1796 - accuracy: 0.9349 - val_loss: 0.2283 - val_accuracy: 0.9113
# Epoch 41/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.1768 - accuracy: 0.9370 - val_loss: 0.2250 - val_accuracy: 0.9154
# Epoch 42/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.1736 - accuracy: 0.9374 - val_loss: 0.2237 - val_accuracy: 0.9113
# Epoch 43/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.1718 - accuracy: 0.9388 - val_loss: 0.2221 - val_accuracy: 0.9093
# Epoch 44/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.1701 - accuracy: 0.9409 - val_loss: 0.2201 - val_accuracy: 0.9134
# Epoch 45/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.1678 - accuracy: 0.9405 - val_loss: 0.2169 - val_accuracy: 0.9154
# Epoch 46/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.1654 - accuracy: 0.9417 - val_loss: 0.2162 - val_accuracy: 0.9185
# Epoch 47/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.1628 - accuracy: 0.9426 - val_loss: 0.2136 - val_accuracy: 0.9144
# Epoch 48/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.1617 - accuracy: 0.9420 - val_loss: 0.2131 - val_accuracy: 0.9164
# Epoch 49/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.1595 - accuracy: 0.9443 - val_loss: 0.2104 - val_accuracy: 0.9174
# Epoch 50/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.1572 - accuracy: 0.9438 - val_loss: 0.2098 - val_accuracy: 0.9144
# Epoch 51/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.1554 - accuracy: 0.9462 - val_loss: 0.2075 - val_accuracy: 0.9195
# Epoch 52/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.1535 - accuracy: 0.9477 - val_loss: 0.2079 - val_accuracy: 0.9195
# Epoch 53/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.1515 - accuracy: 0.9475 - val_loss: 0.2057 - val_accuracy: 0.9215
# Epoch 54/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.1501 - accuracy: 0.9481 - val_loss: 0.2032 - val_accuracy: 0.9235
# Epoch 55/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.1479 - accuracy: 0.9486 - val_loss: 0.2049 - val_accuracy: 0.9225
# Epoch 56/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.1463 - accuracy: 0.9502 - val_loss: 0.2016 - val_accuracy: 0.9246
# Epoch 57/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.1446 - accuracy: 0.9519 - val_loss: 0.2002 - val_accuracy: 0.9235
# Epoch 58/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.1436 - accuracy: 0.9519 - val_loss: 0.1992 - val_accuracy: 0.9256
# Epoch 59/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.1415 - accuracy: 0.9516 - val_loss: 0.1966 - val_accuracy: 0.9246
# Epoch 60/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.1394 - accuracy: 0.9530 - val_loss: 0.1969 - val_accuracy: 0.9276
# Epoch 61/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.1381 - accuracy: 0.9526 - val_loss: 0.1958 - val_accuracy: 0.9256
# Epoch 62/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.1367 - accuracy: 0.9539 - val_loss: 0.1939 - val_accuracy: 0.9235
# Epoch 63/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.1349 - accuracy: 0.9550 - val_loss: 0.1933 - val_accuracy: 0.9266
# Epoch 64/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.1342 - accuracy: 0.9547 - val_loss: 0.1924 - val_accuracy: 0.9286
# Epoch 65/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.1314 - accuracy: 0.9564 - val_loss: 0.1922 - val_accuracy: 0.9286
# Epoch 66/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.1301 - accuracy: 0.9562 - val_loss: 0.1908 - val_accuracy: 0.9266
# Epoch 67/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.1285 - accuracy: 0.9583 - val_loss: 0.1880 - val_accuracy: 0.9256
# Epoch 68/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.1277 - accuracy: 0.9588 - val_loss: 0.1876 - val_accuracy: 0.9297
# Epoch 69/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.1263 - accuracy: 0.9591 - val_loss: 0.1858 - val_accuracy: 0.9276
# Epoch 70/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.1245 - accuracy: 0.9590 - val_loss: 0.1846 - val_accuracy: 0.9266
# Epoch 71/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.1230 - accuracy: 0.9607 - val_loss: 0.1836 - val_accuracy: 0.9266
# Epoch 72/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.1217 - accuracy: 0.9606 - val_loss: 0.1820 - val_accuracy: 0.9286
# Epoch 73/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.1205 - accuracy: 0.9622 - val_loss: 0.1825 - val_accuracy: 0.9297
# Epoch 74/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.1204 - accuracy: 0.9609 - val_loss: 0.1837 - val_accuracy: 0.9297
# Epoch 75/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.1182 - accuracy: 0.9628 - val_loss: 0.1786 - val_accuracy: 0.9317
# Epoch 76/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.1165 - accuracy: 0.9624 - val_loss: 0.1804 - val_accuracy: 0.9286
# Epoch 77/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.1158 - accuracy: 0.9626 - val_loss: 0.1762 - val_accuracy: 0.9327
# Epoch 78/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.1144 - accuracy: 0.9644 - val_loss: 0.1752 - val_accuracy: 0.9358
# Epoch 79/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.1133 - accuracy: 0.9640 - val_loss: 0.1765 - val_accuracy: 0.9378
# Epoch 80/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.1115 - accuracy: 0.9652 - val_loss: 0.1740 - val_accuracy: 0.9317
# Epoch 81/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.1108 - accuracy: 0.9659 - val_loss: 0.1741 - val_accuracy: 0.9348
# Epoch 82/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.1089 - accuracy: 0.9654 - val_loss: 0.1722 - val_accuracy: 0.9368
# Epoch 83/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.1087 - accuracy: 0.9669 - val_loss: 0.1712 - val_accuracy: 0.9388
# Epoch 84/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.1060 - accuracy: 0.9667 - val_loss: 0.1688 - val_accuracy: 0.9388
# Epoch 85/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.1060 - accuracy: 0.9664 - val_loss: 0.1692 - val_accuracy: 0.9368
# Epoch 86/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.1039 - accuracy: 0.9677 - val_loss: 0.1703 - val_accuracy: 0.9348
# Epoch 87/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.1035 - accuracy: 0.9660 - val_loss: 0.1704 - val_accuracy: 0.9368
# Epoch 88/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.1024 - accuracy: 0.9681 - val_loss: 0.1672 - val_accuracy: 0.9409
# Epoch 89/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.1006 - accuracy: 0.9686 - val_loss: 0.1678 - val_accuracy: 0.9399
# Epoch 90/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0998 - accuracy: 0.9696 - val_loss: 0.1643 - val_accuracy: 0.9419
# Epoch 91/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.1003 - accuracy: 0.9691 - val_loss: 0.1679 - val_accuracy: 0.9348
# Epoch 92/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0979 - accuracy: 0.9703 - val_loss: 0.1645 - val_accuracy: 0.9419
# Epoch 93/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0964 - accuracy: 0.9718 - val_loss: 0.1646 - val_accuracy: 0.9388
# Epoch 94/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0967 - accuracy: 0.9710 - val_loss: 0.1606 - val_accuracy: 0.9399
# Epoch 95/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0955 - accuracy: 0.9704 - val_loss: 0.1640 - val_accuracy: 0.9409
# Epoch 96/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0943 - accuracy: 0.9717 - val_loss: 0.1592 - val_accuracy: 0.9419
# Epoch 97/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0925 - accuracy: 0.9721 - val_loss: 0.1591 - val_accuracy: 0.9409
# Epoch 98/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0915 - accuracy: 0.9724 - val_loss: 0.1568 - val_accuracy: 0.9439
# Epoch 99/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0905 - accuracy: 0.9737 - val_loss: 0.1569 - val_accuracy: 0.9439
# Epoch 100/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0888 - accuracy: 0.9747 - val_loss: 0.1643 - val_accuracy: 0.9439
# Epoch 101/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0891 - accuracy: 0.9730 - val_loss: 0.1616 - val_accuracy: 0.9419
# Epoch 102/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0878 - accuracy: 0.9733 - val_loss: 0.1586 - val_accuracy: 0.9439
# Epoch 103/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0872 - accuracy: 0.9742 - val_loss: 0.1557 - val_accuracy: 0.9399
# Epoch 104/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0859 - accuracy: 0.9746 - val_loss: 0.1530 - val_accuracy: 0.9419
# Epoch 105/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0845 - accuracy: 0.9751 - val_loss: 0.1532 - val_accuracy: 0.9409
# Epoch 106/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0842 - accuracy: 0.9748 - val_loss: 0.1524 - val_accuracy: 0.9450
# Epoch 107/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0830 - accuracy: 0.9756 - val_loss: 0.1513 - val_accuracy: 0.9439
# Epoch 108/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0817 - accuracy: 0.9763 - val_loss: 0.1537 - val_accuracy: 0.9388
# Epoch 109/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0818 - accuracy: 0.9770 - val_loss: 0.1552 - val_accuracy: 0.9429
# Epoch 110/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0804 - accuracy: 0.9779 - val_loss: 0.1487 - val_accuracy: 0.9429
# Epoch 111/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0796 - accuracy: 0.9771 - val_loss: 0.1526 - val_accuracy: 0.9460
# Epoch 112/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0778 - accuracy: 0.9779 - val_loss: 0.1485 - val_accuracy: 0.9429
# Epoch 113/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0778 - accuracy: 0.9773 - val_loss: 0.1458 - val_accuracy: 0.9429
# Epoch 114/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0768 - accuracy: 0.9788 - val_loss: 0.1480 - val_accuracy: 0.9470
# Epoch 115/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0761 - accuracy: 0.9780 - val_loss: 0.1458 - val_accuracy: 0.9460
# Epoch 116/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0757 - accuracy: 0.9781 - val_loss: 0.1466 - val_accuracy: 0.9460
# Epoch 117/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0746 - accuracy: 0.9794 - val_loss: 0.1463 - val_accuracy: 0.9439
# Epoch 118/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0740 - accuracy: 0.9789 - val_loss: 0.1441 - val_accuracy: 0.9480
# Epoch 119/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0728 - accuracy: 0.9797 - val_loss: 0.1510 - val_accuracy: 0.9439
# Epoch 120/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0725 - accuracy: 0.9798 - val_loss: 0.1454 - val_accuracy: 0.9439
# Epoch 121/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0714 - accuracy: 0.9796 - val_loss: 0.1472 - val_accuracy: 0.9439
# Epoch 122/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0711 - accuracy: 0.9803 - val_loss: 0.1425 - val_accuracy: 0.9470
# Epoch 123/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0710 - accuracy: 0.9803 - val_loss: 0.1417 - val_accuracy: 0.9460
# Epoch 124/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0687 - accuracy: 0.9814 - val_loss: 0.1426 - val_accuracy: 0.9480
# Epoch 125/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0686 - accuracy: 0.9810 - val_loss: 0.1470 - val_accuracy: 0.9429
# Epoch 126/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0677 - accuracy: 0.9810 - val_loss: 0.1400 - val_accuracy: 0.9480
# Epoch 127/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0677 - accuracy: 0.9803 - val_loss: 0.1403 - val_accuracy: 0.9460
# Epoch 128/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0664 - accuracy: 0.9814 - val_loss: 0.1398 - val_accuracy: 0.9460
# Epoch 129/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0657 - accuracy: 0.9819 - val_loss: 0.1421 - val_accuracy: 0.9480
# Epoch 130/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0657 - accuracy: 0.9822 - val_loss: 0.1422 - val_accuracy: 0.9480
# Epoch 131/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0640 - accuracy: 0.9823 - val_loss: 0.1395 - val_accuracy: 0.9450
# Epoch 132/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0634 - accuracy: 0.9833 - val_loss: 0.1373 - val_accuracy: 0.9490
# Epoch 133/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0631 - accuracy: 0.9826 - val_loss: 0.1456 - val_accuracy: 0.9541
# Epoch 134/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0625 - accuracy: 0.9828 - val_loss: 0.1365 - val_accuracy: 0.9511
# Epoch 135/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0618 - accuracy: 0.9833 - val_loss: 0.1380 - val_accuracy: 0.9521
# Epoch 136/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0601 - accuracy: 0.9844 - val_loss: 0.1385 - val_accuracy: 0.9480
# Epoch 137/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0596 - accuracy: 0.9848 - val_loss: 0.1353 - val_accuracy: 0.9501
# Epoch 138/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0587 - accuracy: 0.9847 - val_loss: 0.1348 - val_accuracy: 0.9480
# Epoch 139/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0587 - accuracy: 0.9843 - val_loss: 0.1410 - val_accuracy: 0.9490
# Epoch 140/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0575 - accuracy: 0.9847 - val_loss: 0.1322 - val_accuracy: 0.9470
# Epoch 141/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0573 - accuracy: 0.9855 - val_loss: 0.1417 - val_accuracy: 0.9511
# Epoch 142/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0568 - accuracy: 0.9847 - val_loss: 0.1331 - val_accuracy: 0.9490
# Epoch 143/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0564 - accuracy: 0.9861 - val_loss: 0.1339 - val_accuracy: 0.9501
# Epoch 144/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0549 - accuracy: 0.9860 - val_loss: 0.1296 - val_accuracy: 0.9501
# Epoch 145/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0545 - accuracy: 0.9865 - val_loss: 0.1294 - val_accuracy: 0.9511
# Epoch 146/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0540 - accuracy: 0.9865 - val_loss: 0.1322 - val_accuracy: 0.9531
# Epoch 147/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0536 - accuracy: 0.9857 - val_loss: 0.1316 - val_accuracy: 0.9511
# Epoch 148/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0532 - accuracy: 0.9862 - val_loss: 0.1305 - val_accuracy: 0.9511
# Epoch 149/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0519 - accuracy: 0.9877 - val_loss: 0.1306 - val_accuracy: 0.9511
# Epoch 150/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0516 - accuracy: 0.9864 - val_loss: 0.1352 - val_accuracy: 0.9521
# Epoch 151/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0514 - accuracy: 0.9871 - val_loss: 0.1281 - val_accuracy: 0.9521
# Epoch 152/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0502 - accuracy: 0.9881 - val_loss: 0.1262 - val_accuracy: 0.9531
# Epoch 153/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0500 - accuracy: 0.9869 - val_loss: 0.1259 - val_accuracy: 0.9551
# Epoch 154/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0488 - accuracy: 0.9883 - val_loss: 0.1287 - val_accuracy: 0.9541
# Epoch 155/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0486 - accuracy: 0.9880 - val_loss: 0.1281 - val_accuracy: 0.9531
# Epoch 156/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0481 - accuracy: 0.9889 - val_loss: 0.1255 - val_accuracy: 0.9531
# Epoch 157/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0475 - accuracy: 0.9883 - val_loss: 0.1271 - val_accuracy: 0.9531
# Epoch 158/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0472 - accuracy: 0.9887 - val_loss: 0.1294 - val_accuracy: 0.9541
# Epoch 159/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0466 - accuracy: 0.9881 - val_loss: 0.1236 - val_accuracy: 0.9551
# Epoch 160/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0465 - accuracy: 0.9888 - val_loss: 0.1256 - val_accuracy: 0.9562
# Epoch 161/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0452 - accuracy: 0.9891 - val_loss: 0.1277 - val_accuracy: 0.9572
# Epoch 162/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0447 - accuracy: 0.9898 - val_loss: 0.1230 - val_accuracy: 0.9541
# Epoch 163/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0451 - accuracy: 0.9891 - val_loss: 0.1218 - val_accuracy: 0.9572
# Epoch 164/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0433 - accuracy: 0.9900 - val_loss: 0.1232 - val_accuracy: 0.9551
# Epoch 165/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0441 - accuracy: 0.9894 - val_loss: 0.1306 - val_accuracy: 0.9572
# Epoch 166/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0429 - accuracy: 0.9895 - val_loss: 0.1310 - val_accuracy: 0.9562
# Epoch 167/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0428 - accuracy: 0.9901 - val_loss: 0.1216 - val_accuracy: 0.9562
# Epoch 168/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0425 - accuracy: 0.9901 - val_loss: 0.1230 - val_accuracy: 0.9582
# Epoch 169/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0416 - accuracy: 0.9904 - val_loss: 0.1221 - val_accuracy: 0.9551
# Epoch 170/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0408 - accuracy: 0.9899 - val_loss: 0.1210 - val_accuracy: 0.9531
# Epoch 171/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0407 - accuracy: 0.9900 - val_loss: 0.1242 - val_accuracy: 0.9551
# Epoch 172/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0403 - accuracy: 0.9913 - val_loss: 0.1188 - val_accuracy: 0.9613
# Epoch 173/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0391 - accuracy: 0.9920 - val_loss: 0.1249 - val_accuracy: 0.9582
# Epoch 174/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0393 - accuracy: 0.9908 - val_loss: 0.1191 - val_accuracy: 0.9582
# Epoch 175/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0392 - accuracy: 0.9907 - val_loss: 0.1255 - val_accuracy: 0.9592
# Epoch 176/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0383 - accuracy: 0.9906 - val_loss: 0.1218 - val_accuracy: 0.9562
# Epoch 177/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0376 - accuracy: 0.9915 - val_loss: 0.1259 - val_accuracy: 0.9572
# Epoch 178/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0377 - accuracy: 0.9908 - val_loss: 0.1179 - val_accuracy: 0.9592
# Epoch 179/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0369 - accuracy: 0.9915 - val_loss: 0.1192 - val_accuracy: 0.9572
# Epoch 180/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0363 - accuracy: 0.9920 - val_loss: 0.1208 - val_accuracy: 0.9592
# Epoch 181/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0357 - accuracy: 0.9917 - val_loss: 0.1176 - val_accuracy: 0.9592
# Epoch 182/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0351 - accuracy: 0.9916 - val_loss: 0.1246 - val_accuracy: 0.9572
# Epoch 183/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0354 - accuracy: 0.9917 - val_loss: 0.1172 - val_accuracy: 0.9582
# Epoch 184/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0351 - accuracy: 0.9921 - val_loss: 0.1187 - val_accuracy: 0.9582
# Epoch 185/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0350 - accuracy: 0.9918 - val_loss: 0.1215 - val_accuracy: 0.9541
# Epoch 186/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0342 - accuracy: 0.9920 - val_loss: 0.1250 - val_accuracy: 0.9551
# Epoch 187/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0330 - accuracy: 0.9926 - val_loss: 0.1206 - val_accuracy: 0.9551
# Epoch 188/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0324 - accuracy: 0.9927 - val_loss: 0.1228 - val_accuracy: 0.9623
# Epoch 189/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0322 - accuracy: 0.9923 - val_loss: 0.1238 - val_accuracy: 0.9623
# Epoch 190/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0321 - accuracy: 0.9922 - val_loss: 0.1148 - val_accuracy: 0.9613
# Epoch 191/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0316 - accuracy: 0.9924 - val_loss: 0.1165 - val_accuracy: 0.9613
# Epoch 192/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0313 - accuracy: 0.9925 - val_loss: 0.1185 - val_accuracy: 0.9582
# Epoch 193/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0306 - accuracy: 0.9931 - val_loss: 0.1206 - val_accuracy: 0.9633
# Epoch 194/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0301 - accuracy: 0.9932 - val_loss: 0.1179 - val_accuracy: 0.9602
# Epoch 195/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0304 - accuracy: 0.9933 - val_loss: 0.1215 - val_accuracy: 0.9633
# Epoch 196/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0300 - accuracy: 0.9938 - val_loss: 0.1162 - val_accuracy: 0.9633
# Epoch 197/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0297 - accuracy: 0.9927 - val_loss: 0.1252 - val_accuracy: 0.9623
# Epoch 198/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0295 - accuracy: 0.9933 - val_loss: 0.1219 - val_accuracy: 0.9633
# Epoch 199/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0285 - accuracy: 0.9938 - val_loss: 0.1169 - val_accuracy: 0.9582
# Epoch 200/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0284 - accuracy: 0.9939 - val_loss: 0.1229 - val_accuracy: 0.9613
# Epoch 201/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0277 - accuracy: 0.9940 - val_loss: 0.1177 - val_accuracy: 0.9623
# Epoch 202/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0272 - accuracy: 0.9935 - val_loss: 0.1149 - val_accuracy: 0.9623
# Epoch 203/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0272 - accuracy: 0.9940 - val_loss: 0.1162 - val_accuracy: 0.9602
# Epoch 204/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0264 - accuracy: 0.9939 - val_loss: 0.1187 - val_accuracy: 0.9623
# Epoch 205/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0262 - accuracy: 0.9944 - val_loss: 0.1151 - val_accuracy: 0.9653
# Epoch 206/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0262 - accuracy: 0.9946 - val_loss: 0.1142 - val_accuracy: 0.9633
# Epoch 207/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0257 - accuracy: 0.9942 - val_loss: 0.1144 - val_accuracy: 0.9643
# Epoch 208/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0257 - accuracy: 0.9944 - val_loss: 0.1216 - val_accuracy: 0.9623
# Epoch 209/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0248 - accuracy: 0.9948 - val_loss: 0.1226 - val_accuracy: 0.9633
# Epoch 210/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0248 - accuracy: 0.9949 - val_loss: 0.1182 - val_accuracy: 0.9602
# Epoch 211/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0253 - accuracy: 0.9947 - val_loss: 0.1207 - val_accuracy: 0.9633
# Epoch 212/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0244 - accuracy: 0.9944 - val_loss: 0.1213 - val_accuracy: 0.9623
# Epoch 213/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0247 - accuracy: 0.9938 - val_loss: 0.1183 - val_accuracy: 0.9653
# Epoch 214/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0231 - accuracy: 0.9946 - val_loss: 0.1174 - val_accuracy: 0.9592
# Epoch 215/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0229 - accuracy: 0.9950 - val_loss: 0.1177 - val_accuracy: 0.9643
# Epoch 216/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0226 - accuracy: 0.9951 - val_loss: 0.1105 - val_accuracy: 0.9633
# Epoch 217/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0230 - accuracy: 0.9951 - val_loss: 0.1205 - val_accuracy: 0.9643
# Epoch 218/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0219 - accuracy: 0.9951 - val_loss: 0.1125 - val_accuracy: 0.9623
# Epoch 219/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0220 - accuracy: 0.9957 - val_loss: 0.1140 - val_accuracy: 0.9643
# Epoch 220/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0219 - accuracy: 0.9951 - val_loss: 0.1200 - val_accuracy: 0.9623
# Epoch 221/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0215 - accuracy: 0.9957 - val_loss: 0.1262 - val_accuracy: 0.9613
# Epoch 222/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0217 - accuracy: 0.9954 - val_loss: 0.1177 - val_accuracy: 0.9633
# Epoch 223/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0208 - accuracy: 0.9955 - val_loss: 0.1213 - val_accuracy: 0.9643
# Epoch 224/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0207 - accuracy: 0.9955 - val_loss: 0.1339 - val_accuracy: 0.9602
# Epoch 225/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0203 - accuracy: 0.9956 - val_loss: 0.1126 - val_accuracy: 0.9643
# Epoch 226/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0204 - accuracy: 0.9960 - val_loss: 0.1258 - val_accuracy: 0.9623
# Epoch 227/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0206 - accuracy: 0.9955 - val_loss: 0.1135 - val_accuracy: 0.9653
# Epoch 228/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0198 - accuracy: 0.9961 - val_loss: 0.1188 - val_accuracy: 0.9653
# Epoch 229/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0202 - accuracy: 0.9955 - val_loss: 0.1104 - val_accuracy: 0.9643
# Epoch 230/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0190 - accuracy: 0.9960 - val_loss: 0.1184 - val_accuracy: 0.9653
# Epoch 231/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0195 - accuracy: 0.9961 - val_loss: 0.1175 - val_accuracy: 0.9643
# Epoch 232/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0189 - accuracy: 0.9958 - val_loss: 0.1173 - val_accuracy: 0.9643
# Epoch 233/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0185 - accuracy: 0.9960 - val_loss: 0.1168 - val_accuracy: 0.9643
# Epoch 234/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0182 - accuracy: 0.9964 - val_loss: 0.1153 - val_accuracy: 0.9664
# Epoch 235/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0176 - accuracy: 0.9963 - val_loss: 0.1064 - val_accuracy: 0.9653
# Epoch 236/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0177 - accuracy: 0.9964 - val_loss: 0.1156 - val_accuracy: 0.9643
# Epoch 237/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0172 - accuracy: 0.9966 - val_loss: 0.1106 - val_accuracy: 0.9633
# Epoch 238/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0170 - accuracy: 0.9961 - val_loss: 0.1146 - val_accuracy: 0.9643
# Epoch 239/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0169 - accuracy: 0.9967 - val_loss: 0.1235 - val_accuracy: 0.9633
# Epoch 240/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0165 - accuracy: 0.9969 - val_loss: 0.1122 - val_accuracy: 0.9653
# Epoch 241/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0170 - accuracy: 0.9967 - val_loss: 0.1152 - val_accuracy: 0.9653
# Epoch 242/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0161 - accuracy: 0.9971 - val_loss: 0.1256 - val_accuracy: 0.9643
# Epoch 243/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0158 - accuracy: 0.9968 - val_loss: 0.1274 - val_accuracy: 0.9643
# Epoch 244/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0164 - accuracy: 0.9966 - val_loss: 0.1205 - val_accuracy: 0.9653
# Epoch 245/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0152 - accuracy: 0.9972 - val_loss: 0.1184 - val_accuracy: 0.9633
# Epoch 246/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0151 - accuracy: 0.9967 - val_loss: 0.1275 - val_accuracy: 0.9643
# Epoch 247/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0150 - accuracy: 0.9971 - val_loss: 0.1212 - val_accuracy: 0.9633
# Epoch 248/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0152 - accuracy: 0.9969 - val_loss: 0.1221 - val_accuracy: 0.9643
# Epoch 249/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0147 - accuracy: 0.9973 - val_loss: 0.1115 - val_accuracy: 0.9653
# Epoch 250/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0143 - accuracy: 0.9973 - val_loss: 0.1217 - val_accuracy: 0.9643
# Epoch 251/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0142 - accuracy: 0.9973 - val_loss: 0.1184 - val_accuracy: 0.9643
# Epoch 252/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0139 - accuracy: 0.9976 - val_loss: 0.1166 - val_accuracy: 0.9613
# Epoch 253/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0151 - accuracy: 0.9974 - val_loss: 0.1136 - val_accuracy: 0.9653
# Epoch 254/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0137 - accuracy: 0.9977 - val_loss: 0.1264 - val_accuracy: 0.9643
# Epoch 255/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0136 - accuracy: 0.9973 - val_loss: 0.1269 - val_accuracy: 0.9653
# Epoch 256/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0135 - accuracy: 0.9975 - val_loss: 0.1273 - val_accuracy: 0.9653
# Epoch 257/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0134 - accuracy: 0.9978 - val_loss: 0.1155 - val_accuracy: 0.9664
# Epoch 258/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0128 - accuracy: 0.9978 - val_loss: 0.1262 - val_accuracy: 0.9633
# Epoch 259/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0129 - accuracy: 0.9977 - val_loss: 0.1249 - val_accuracy: 0.9633
# Epoch 260/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0126 - accuracy: 0.9980 - val_loss: 0.1054 - val_accuracy: 0.9704
# Epoch 261/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0123 - accuracy: 0.9982 - val_loss: 0.1171 - val_accuracy: 0.9623
# Epoch 262/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0121 - accuracy: 0.9980 - val_loss: 0.1173 - val_accuracy: 0.9664
# Epoch 263/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0118 - accuracy: 0.9981 - val_loss: 0.1360 - val_accuracy: 0.9623
# Epoch 264/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0116 - accuracy: 0.9982 - val_loss: 0.1166 - val_accuracy: 0.9664
# Epoch 265/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0115 - accuracy: 0.9980 - val_loss: 0.1104 - val_accuracy: 0.9694
# Epoch 266/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0113 - accuracy: 0.9983 - val_loss: 0.1240 - val_accuracy: 0.9633
# Epoch 267/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0115 - accuracy: 0.9988 - val_loss: 0.1059 - val_accuracy: 0.9684
# Epoch 268/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0116 - accuracy: 0.9982 - val_loss: 0.1140 - val_accuracy: 0.9674
# Epoch 269/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0112 - accuracy: 0.9976 - val_loss: 0.1222 - val_accuracy: 0.9653
# Epoch 270/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0116 - accuracy: 0.9984 - val_loss: 0.1246 - val_accuracy: 0.9684
# Epoch 271/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0113 - accuracy: 0.9982 - val_loss: 0.1294 - val_accuracy: 0.9674
# Epoch 272/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0104 - accuracy: 0.9983 - val_loss: 0.1132 - val_accuracy: 0.9674
# Epoch 273/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0099 - accuracy: 0.9984 - val_loss: 0.1181 - val_accuracy: 0.9664
# Epoch 274/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0101 - accuracy: 0.9985 - val_loss: 0.1105 - val_accuracy: 0.9674
# Epoch 275/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0103 - accuracy: 0.9986 - val_loss: 0.1093 - val_accuracy: 0.9694
# Epoch 276/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0097 - accuracy: 0.9986 - val_loss: 0.1215 - val_accuracy: 0.9643
# Epoch 277/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0099 - accuracy: 0.9984 - val_loss: 0.1225 - val_accuracy: 0.9643
# Epoch 278/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0095 - accuracy: 0.9988 - val_loss: 0.1206 - val_accuracy: 0.9643
# Epoch 279/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0095 - accuracy: 0.9983 - val_loss: 0.1302 - val_accuracy: 0.9653
# Epoch 280/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0093 - accuracy: 0.9984 - val_loss: 0.1109 - val_accuracy: 0.9715
# Epoch 281/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0097 - accuracy: 0.9985 - val_loss: 0.1301 - val_accuracy: 0.9674
# Epoch 282/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0092 - accuracy: 0.9988 - val_loss: 0.1193 - val_accuracy: 0.9643
# Epoch 283/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0090 - accuracy: 0.9989 - val_loss: 0.1168 - val_accuracy: 0.9653
# Epoch 284/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0090 - accuracy: 0.9989 - val_loss: 0.1270 - val_accuracy: 0.9664
# Epoch 285/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0093 - accuracy: 0.9986 - val_loss: 0.1191 - val_accuracy: 0.9664
# Epoch 286/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0087 - accuracy: 0.9990 - val_loss: 0.1175 - val_accuracy: 0.9653
# Epoch 287/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0086 - accuracy: 0.9989 - val_loss: 0.1111 - val_accuracy: 0.9704
# Epoch 288/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0082 - accuracy: 0.9988 - val_loss: 0.1185 - val_accuracy: 0.9653
# Epoch 289/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0084 - accuracy: 0.9991 - val_loss: 0.1208 - val_accuracy: 0.9684
# Epoch 290/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0082 - accuracy: 0.9991 - val_loss: 0.1193 - val_accuracy: 0.9653
# Epoch 291/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0078 - accuracy: 0.9991 - val_loss: 0.1268 - val_accuracy: 0.9643
# Epoch 292/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0076 - accuracy: 0.9992 - val_loss: 0.1219 - val_accuracy: 0.9674
# Epoch 293/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0074 - accuracy: 0.9990 - val_loss: 0.1292 - val_accuracy: 0.9653
# Epoch 294/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0075 - accuracy: 0.9991 - val_loss: 0.1128 - val_accuracy: 0.9694
# Epoch 295/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0075 - accuracy: 0.9991 - val_loss: 0.1214 - val_accuracy: 0.9653
# Epoch 296/300
# 69/69 [==============================] - 0s 2ms/step - loss: 0.0072 - accuracy: 0.9991 - val_loss: 0.1241 - val_accuracy: 0.9674
# Epoch 297/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0071 - accuracy: 0.9992 - val_loss: 0.1209 - val_accuracy: 0.9684
# Epoch 298/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0070 - accuracy: 0.9993 - val_loss: 0.1254 - val_accuracy: 0.9664
# Epoch 299/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0070 - accuracy: 0.9992 - val_loss: 0.1206 - val_accuracy: 0.9674
# Epoch 300/300
# 69/69 [==============================] - 0s 1ms/step - loss: 0.0067 - accuracy: 0.9993 - val_loss: 0.1365 - val_accuracy: 0.9633

# %%
ytt=nural_network.predict(xtest)
dd=np.round(ytt)
# Out:
# 31/31 [==============================] - 0s 521us/step
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.93      0.96       481
#          1.0       0.93      1.00      0.97       500
#
#     accuracy                           0.96       981
#    macro avg       0.97      0.96      0.96       981
# weighted avg       0.97      0.96      0.96       981

# %%
# Create a DataFrame with the provided column names
column_names = [
    "ClaimID",
    "Bene_ID",
    "AttendingPhysician",
    "OperatingPhysician",
    "ClmDiagnosisCode",
    "ClmProcedureCode",
    "Provider",
    "InscClaimAmtReimbursed",
    "ClaimStartDt / ClaimEndDt",
    "AdmissionDt / DischargeDt",
    "Bene_ID",
    "DOB",
    "Gender",
    "State/Country",
    "Premedical conditions",
    "Provider",
    "Target",
    "eAdmitForDays",
    "DeductibleAmtPaid",
    "DiagnosisCodePresent",
    "Departed"
]

# Assuming 'data' is your DataFrame
# If not, replace 'data' with your actual DataFrame name
data = grouped[column_names]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[54], line 28
#       2 column_names = [
#       3     "ClaimID",
#       4     "Bene_ID",
#    (...)
#      23     "Departed"
#      24 ]
#      26 # Assuming 'data' is your DataFrame
#      27 # If not, replace 'data' with your actual DataFrame name
# ---> 28 data = grouped[column_names]
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:5877, in Index._get_indexer_strict(self, key, axis_name)
#    5874 else:
#    5875     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5877 self._raise_if_missing(keyarr, indexer, axis_name)
#    5879 keyarr = self.take(indexer)
#    5880 if isinstance(key, Index):
#    5881     # GH 42790 - Preserve name from an Index
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:5941, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5938     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5940 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5941 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['ClaimID', 'Bene_ID', 'AttendingPhysician', 'OperatingPhysician', 'ClmDiagnosisCode', 'ClmProcedureCode', 'InscClaimAmtReimbursed', 'ClaimStartDt / ClaimEndDt', 'AdmissionDt / DischargeDt', 'DOB', 'Gender', 'State/Country', 'Premedical conditions', 'Target', 'eAdmitForDays', 'DeductibleAmtPaid', 'DiagnosisCodePresent', 'Departed'] not in index"
